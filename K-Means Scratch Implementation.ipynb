# %%
'''
Fundamentals of K-Means Clustering
We have to provide the value of 'k'. Inappropriate value of k may result in poor cluster perfomance
https://towardsdatascience.com/k-means-clustering-with-scikit-learn-6b47a369a83c
https://stackoverflow.com/questions/1401712/how-can-the-euclidean-distance-be-calculated-with-numpy
https://semantive.com/high-performance-computation-in-python-numpy-2/
'''

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

df = pd.read_csv("wt-ht.csv")
X = []
X.append(df['Height'])
#X.append(df['Weight'])
#for x in X:
    
Y = df['Weight']
plt.scatter(X,Y)
plt.show()
